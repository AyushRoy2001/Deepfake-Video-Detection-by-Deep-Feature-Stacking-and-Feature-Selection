# %%
with open('Main_Test.csv', 'w') as creating_new_csv_file: 
   pass 
print("Empty File Created Successfully")
# Out:
# Empty File Created Successfully

# %%
import tensorflow as tf
import os
import glob
import numpy as np
import cv2
import random

# %%
train_files = []

for x in os.walk('/kaggle/input/deepfake/FaceForensic/FaceForensic/train'):
    for y in glob.glob(os.path.join(x[0], '*.png')):
        train_files.append(y)
random.shuffle(train_files)
print(len(train_files))
# Out:
# 5876

# %%
valid_files = []
for x in os.walk('/kaggle/input/deepfake/FaceForensic/FaceForensic/validation'):
    for y in glob.glob(os.path.join(x[0], '*.png')):
        valid_files.append(y)
random.shuffle(valid_files)
print(len(valid_files))
# Out:
# 395

# %%
def get_input(path):
    im = cv2.imread(path)
    im = cv2.resize(im, (244, 244))
    #im = im.reshape(-1,244,244,3)
    
    return(im)
 
def get_output(path):
    labaF = [1,0]
    labaT = [0,1]
    label = (path.split('/')[-1]).split('_')[0]
    if 'fake' == label:
        return labaF
    else:
        return labaT

# %%
#mod = Xception(include_top=False, weights='imagenet', input_shape=(299,299,3), pooling='Avg', classes=1000)

mod = tf.keras.applications.DenseNet121(include_top=True, weights='imagenet', input_shape=(224,224,3), pooling='Avg', classes=1000)
for layer in mod.layers:
    mod.trainable = True
layer = tf.keras.layers.Dense(512, activation='relu')(mod.layers[-2].output)
layer = tf.keras.layers.Dense(2, activation='softmax')(layer)
mod = tf.keras.models.Model(inputs=mod.input, outputs=layer)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels.h5
# 33188688/33188688 [==============================] - 0s 0us/step

# %%
def image_generator(files, batch_size, resize=None):
 
      while True:
          batch_paths  = np.random.choice(a = files, size = batch_size)
          batch_x = []
          batch_y = [] 
          
          for input_path in batch_paths:
              input = get_input(input_path)
              output = get_output(input_path)
              if resize is not None:
                input = cv2.resize(input, resize)
              batch_x.append(input)
              batch_y.append(output)
          batch_x = np.array(batch_x)
          batch_y = np.array(batch_y)
          yield batch_x, batch_y

# %%
#ATTENTION APPROACH 2(USING AMNET MODEL WITH INCEPTION AS CORE CNN) WITH 512 ATTENTION NODE (ON FACESWAP)
mod.compile('Adam', loss = tf.keras.losses.CategoricalCrossentropy(), metrics = ['accuracy', tf.keras.metrics.AUC()])
mod.summary()
checkpoint_filepath = '/kaggle/working/checkpoint'
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_filepath, save_best_only=True, save_weights_only=False, monitor='val_accuracy', mode='max')
 
history = mod.fit(image_generator(train_files, batch_size = 32), epochs = 100, steps_per_epoch = 40, validation_data = image_generator(valid_files, batch_size = 32), validation_steps = 15, callbacks=[model_checkpoint_callback])
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  zero_padding2d (ZeroPadding2D)  (None, 230, 230, 3)  0          ['input_1[0][0]']
#
#  conv1/conv (Conv2D)            (None, 112, 112, 64  9408        ['zero_padding2d[0][0]']
#                                 )
#
#  conv1/bn (BatchNormalization)  (None, 112, 112, 64  256         ['conv1/conv[0][0]']
#                                 )
#
#  conv1/relu (Activation)        (None, 112, 112, 64  0           ['conv1/bn[0][0]']
#                                 )
#
#  zero_padding2d_1 (ZeroPadding2  (None, 114, 114, 64  0          ['conv1/relu[0][0]']
#  D)                             )
#
#  pool1 (MaxPooling2D)           (None, 56, 56, 64)   0           ['zero_padding2d_1[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 56, 56, 64)  256         ['pool1[0][0]']
#  ization)
#
#  conv2_block1_0_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_0_bn[0][0]']
#  n)
#
#  conv2_block1_1_conv (Conv2D)   (None, 56, 56, 128)  8192        ['conv2_block1_0_relu[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 56, 56, 128)  512        ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 56, 56, 128)  0          ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 56, 56, 32)   36864       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_concat (Concatena  (None, 56, 56, 96)  0           ['pool1[0][0]',
#  te)                                                              'conv2_block1_2_conv[0][0]']
#
#  conv2_block2_0_bn (BatchNormal  (None, 56, 56, 96)  384         ['conv2_block1_concat[0][0]']
#  ization)
#
#  conv2_block2_0_relu (Activatio  (None, 56, 56, 96)  0           ['conv2_block2_0_bn[0][0]']
#  n)
#
#  conv2_block2_1_conv (Conv2D)   (None, 56, 56, 128)  12288       ['conv2_block2_0_relu[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 56, 56, 128)  512        ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 56, 56, 128)  0          ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 56, 56, 32)   36864       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_concat (Concatena  (None, 56, 56, 128)  0          ['conv2_block1_concat[0][0]',
#  te)                                                              'conv2_block2_2_conv[0][0]']
#
#  conv2_block3_0_bn (BatchNormal  (None, 56, 56, 128)  512        ['conv2_block2_concat[0][0]']
#  ization)
#
#  conv2_block3_0_relu (Activatio  (None, 56, 56, 128)  0          ['conv2_block3_0_bn[0][0]']
#  n)
#
#  conv2_block3_1_conv (Conv2D)   (None, 56, 56, 128)  16384       ['conv2_block3_0_relu[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 56, 56, 128)  512        ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 56, 56, 128)  0          ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 56, 56, 32)   36864       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_concat (Concatena  (None, 56, 56, 160)  0          ['conv2_block2_concat[0][0]',
#  te)                                                              'conv2_block3_2_conv[0][0]']
#
#  conv2_block4_0_bn (BatchNormal  (None, 56, 56, 160)  640        ['conv2_block3_concat[0][0]']
#  ization)
#
#  conv2_block4_0_relu (Activatio  (None, 56, 56, 160)  0          ['conv2_block4_0_bn[0][0]']
#  n)
#
#  conv2_block4_1_conv (Conv2D)   (None, 56, 56, 128)  20480       ['conv2_block4_0_relu[0][0]']
#
#  conv2_block4_1_bn (BatchNormal  (None, 56, 56, 128)  512        ['conv2_block4_1_conv[0][0]']
#  ization)
#
#  conv2_block4_1_relu (Activatio  (None, 56, 56, 128)  0          ['conv2_block4_1_bn[0][0]']
#  n)
#
#  conv2_block4_2_conv (Conv2D)   (None, 56, 56, 32)   36864       ['conv2_block4_1_relu[0][0]']
#
#  conv2_block4_concat (Concatena  (None, 56, 56, 192)  0          ['conv2_block3_concat[0][0]',
#  te)                                                              'conv2_block4_2_conv[0][0]']
#
#  conv2_block5_0_bn (BatchNormal  (None, 56, 56, 192)  768        ['conv2_block4_concat[0][0]']
#  ization)
#
#  conv2_block5_0_relu (Activatio  (None, 56, 56, 192)  0          ['conv2_block5_0_bn[0][0]']
#  n)
#
#  conv2_block5_1_conv (Conv2D)   (None, 56, 56, 128)  24576       ['conv2_block5_0_relu[0][0]']
#
#  conv2_block5_1_bn (BatchNormal  (None, 56, 56, 128)  512        ['conv2_block5_1_conv[0][0]']
#  ization)
#
#  conv2_block5_1_relu (Activatio  (None, 56, 56, 128)  0          ['conv2_block5_1_bn[0][0]']
#  n)
#
#  conv2_block5_2_conv (Conv2D)   (None, 56, 56, 32)   36864       ['conv2_block5_1_relu[0][0]']
#
#  conv2_block5_concat (Concatena  (None, 56, 56, 224)  0          ['conv2_block4_concat[0][0]',
#  te)                                                              'conv2_block5_2_conv[0][0]']
#
#  conv2_block6_0_bn (BatchNormal  (None, 56, 56, 224)  896        ['conv2_block5_concat[0][0]']
#  ization)
#
#  conv2_block6_0_relu (Activatio  (None, 56, 56, 224)  0          ['conv2_block6_0_bn[0][0]']
#  n)
#
#  conv2_block6_1_conv (Conv2D)   (None, 56, 56, 128)  28672       ['conv2_block6_0_relu[0][0]']
#
#  conv2_block6_1_bn (BatchNormal  (None, 56, 56, 128)  512        ['conv2_block6_1_conv[0][0]']
#  ization)
#
#  conv2_block6_1_relu (Activatio  (None, 56, 56, 128)  0          ['conv2_block6_1_bn[0][0]']
#  n)
#
#  conv2_block6_2_conv (Conv2D)   (None, 56, 56, 32)   36864       ['conv2_block6_1_relu[0][0]']
#
#  conv2_block6_concat (Concatena  (None, 56, 56, 256)  0          ['conv2_block5_concat[0][0]',
#  te)                                                              'conv2_block6_2_conv[0][0]']
#
#  pool2_bn (BatchNormalization)  (None, 56, 56, 256)  1024        ['conv2_block6_concat[0][0]']
#
#  pool2_relu (Activation)        (None, 56, 56, 256)  0           ['pool2_bn[0][0]']
#
#  pool2_conv (Conv2D)            (None, 56, 56, 128)  32768       ['pool2_relu[0][0]']
#
#  pool2_pool (AveragePooling2D)  (None, 28, 28, 128)  0           ['pool2_conv[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 28, 28, 128)  512        ['pool2_pool[0][0]']
#  ization)
#
#  conv3_block1_0_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_0_bn[0][0]']
#  n)
#
#  conv3_block1_1_conv (Conv2D)   (None, 28, 28, 128)  16384       ['conv3_block1_0_relu[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_concat (Concatena  (None, 28, 28, 160)  0          ['pool2_pool[0][0]',
#  te)                                                              'conv3_block1_2_conv[0][0]']
#
#  conv3_block2_0_bn (BatchNormal  (None, 28, 28, 160)  640        ['conv3_block1_concat[0][0]']
#  ization)
#
#  conv3_block2_0_relu (Activatio  (None, 28, 28, 160)  0          ['conv3_block2_0_bn[0][0]']
#  n)
#
#  conv3_block2_1_conv (Conv2D)   (None, 28, 28, 128)  20480       ['conv3_block2_0_relu[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_concat (Concatena  (None, 28, 28, 192)  0          ['conv3_block1_concat[0][0]',
#  te)                                                              'conv3_block2_2_conv[0][0]']
#
#  conv3_block3_0_bn (BatchNormal  (None, 28, 28, 192)  768        ['conv3_block2_concat[0][0]']
#  ization)
#
#  conv3_block3_0_relu (Activatio  (None, 28, 28, 192)  0          ['conv3_block3_0_bn[0][0]']
#  n)
#
#  conv3_block3_1_conv (Conv2D)   (None, 28, 28, 128)  24576       ['conv3_block3_0_relu[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_concat (Concatena  (None, 28, 28, 224)  0          ['conv3_block2_concat[0][0]',
#  te)                                                              'conv3_block3_2_conv[0][0]']
#
#  conv3_block4_0_bn (BatchNormal  (None, 28, 28, 224)  896        ['conv3_block3_concat[0][0]']
#  ization)
#
#  conv3_block4_0_relu (Activatio  (None, 28, 28, 224)  0          ['conv3_block4_0_bn[0][0]']
#  n)
#
#  conv3_block4_1_conv (Conv2D)   (None, 28, 28, 128)  28672       ['conv3_block4_0_relu[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_concat (Concatena  (None, 28, 28, 256)  0          ['conv3_block3_concat[0][0]',
#  te)                                                              'conv3_block4_2_conv[0][0]']
#
#  conv3_block5_0_bn (BatchNormal  (None, 28, 28, 256)  1024       ['conv3_block4_concat[0][0]']
#  ization)
#
#  conv3_block5_0_relu (Activatio  (None, 28, 28, 256)  0          ['conv3_block5_0_bn[0][0]']
#  n)
#
#  conv3_block5_1_conv (Conv2D)   (None, 28, 28, 128)  32768       ['conv3_block5_0_relu[0][0]']
#
#  conv3_block5_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block5_1_conv[0][0]']
#  ization)
#
#  conv3_block5_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block5_1_bn[0][0]']
#  n)
#
#  conv3_block5_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block5_1_relu[0][0]']
#
#  conv3_block5_concat (Concatena  (None, 28, 28, 288)  0          ['conv3_block4_concat[0][0]',
#  te)                                                              'conv3_block5_2_conv[0][0]']
#
#  conv3_block6_0_bn (BatchNormal  (None, 28, 28, 288)  1152       ['conv3_block5_concat[0][0]']
#  ization)
#
#  conv3_block6_0_relu (Activatio  (None, 28, 28, 288)  0          ['conv3_block6_0_bn[0][0]']
#  n)
#
#  conv3_block6_1_conv (Conv2D)   (None, 28, 28, 128)  36864       ['conv3_block6_0_relu[0][0]']
#
#  conv3_block6_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block6_1_conv[0][0]']
#  ization)
#
#  conv3_block6_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block6_1_bn[0][0]']
#  n)
#
#  conv3_block6_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block6_1_relu[0][0]']
#
#  conv3_block6_concat (Concatena  (None, 28, 28, 320)  0          ['conv3_block5_concat[0][0]',
#  te)                                                              'conv3_block6_2_conv[0][0]']
#
#  conv3_block7_0_bn (BatchNormal  (None, 28, 28, 320)  1280       ['conv3_block6_concat[0][0]']
#  ization)
#
#  conv3_block7_0_relu (Activatio  (None, 28, 28, 320)  0          ['conv3_block7_0_bn[0][0]']
#  n)
#
#  conv3_block7_1_conv (Conv2D)   (None, 28, 28, 128)  40960       ['conv3_block7_0_relu[0][0]']
#
#  conv3_block7_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block7_1_conv[0][0]']
#  ization)
#
#  conv3_block7_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block7_1_bn[0][0]']
#  n)
#
#  conv3_block7_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block7_1_relu[0][0]']
#
#  conv3_block7_concat (Concatena  (None, 28, 28, 352)  0          ['conv3_block6_concat[0][0]',
#  te)                                                              'conv3_block7_2_conv[0][0]']
#
#  conv3_block8_0_bn (BatchNormal  (None, 28, 28, 352)  1408       ['conv3_block7_concat[0][0]']
#  ization)
#
#  conv3_block8_0_relu (Activatio  (None, 28, 28, 352)  0          ['conv3_block8_0_bn[0][0]']
#  n)
#
#  conv3_block8_1_conv (Conv2D)   (None, 28, 28, 128)  45056       ['conv3_block8_0_relu[0][0]']
#
#  conv3_block8_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block8_1_conv[0][0]']
#  ization)
#
#  conv3_block8_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block8_1_bn[0][0]']
#  n)
#
#  conv3_block8_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block8_1_relu[0][0]']
#
#  conv3_block8_concat (Concatena  (None, 28, 28, 384)  0          ['conv3_block7_concat[0][0]',
#  te)                                                              'conv3_block8_2_conv[0][0]']
#
#  conv3_block9_0_bn (BatchNormal  (None, 28, 28, 384)  1536       ['conv3_block8_concat[0][0]']
#  ization)
#
#  conv3_block9_0_relu (Activatio  (None, 28, 28, 384)  0          ['conv3_block9_0_bn[0][0]']
#  n)
#
#  conv3_block9_1_conv (Conv2D)   (None, 28, 28, 128)  49152       ['conv3_block9_0_relu[0][0]']
#
#  conv3_block9_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block9_1_conv[0][0]']
#  ization)
#
#  conv3_block9_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block9_1_bn[0][0]']
#  n)
#
#  conv3_block9_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block9_1_relu[0][0]']
#
#  conv3_block9_concat (Concatena  (None, 28, 28, 416)  0          ['conv3_block8_concat[0][0]',
#  te)                                                              'conv3_block9_2_conv[0][0]']
#
#  conv3_block10_0_bn (BatchNorma  (None, 28, 28, 416)  1664       ['conv3_block9_concat[0][0]']
#  lization)
#
#  conv3_block10_0_relu (Activati  (None, 28, 28, 416)  0          ['conv3_block10_0_bn[0][0]']
#  on)
#
#  conv3_block10_1_conv (Conv2D)  (None, 28, 28, 128)  53248       ['conv3_block10_0_relu[0][0]']
#
#  conv3_block10_1_bn (BatchNorma  (None, 28, 28, 128)  512        ['conv3_block10_1_conv[0][0]']
#  lization)
#
#  conv3_block10_1_relu (Activati  (None, 28, 28, 128)  0          ['conv3_block10_1_bn[0][0]']
#  on)
#
#  conv3_block10_2_conv (Conv2D)  (None, 28, 28, 32)   36864       ['conv3_block10_1_relu[0][0]']
#
#  conv3_block10_concat (Concaten  (None, 28, 28, 448)  0          ['conv3_block9_concat[0][0]',
#  ate)                                                             'conv3_block10_2_conv[0][0]']
#
#  conv3_block11_0_bn (BatchNorma  (None, 28, 28, 448)  1792       ['conv3_block10_concat[0][0]']
#  lization)
#
#  conv3_block11_0_relu (Activati  (None, 28, 28, 448)  0          ['conv3_block11_0_bn[0][0]']
#  on)
#
#  conv3_block11_1_conv (Conv2D)  (None, 28, 28, 128)  57344       ['conv3_block11_0_relu[0][0]']
#
#  conv3_block11_1_bn (BatchNorma  (None, 28, 28, 128)  512        ['conv3_block11_1_conv[0][0]']
#  lization)
#
#  conv3_block11_1_relu (Activati  (None, 28, 28, 128)  0          ['conv3_block11_1_bn[0][0]']
#  on)
#
#  conv3_block11_2_conv (Conv2D)  (None, 28, 28, 32)   36864       ['conv3_block11_1_relu[0][0]']
#
#  conv3_block11_concat (Concaten  (None, 28, 28, 480)  0          ['conv3_block10_concat[0][0]',
#  ate)                                                             'conv3_block11_2_conv[0][0]']
#
#  conv3_block12_0_bn (BatchNorma  (None, 28, 28, 480)  1920       ['conv3_block11_concat[0][0]']
#  lization)
#
#  conv3_block12_0_relu (Activati  (None, 28, 28, 480)  0          ['conv3_block12_0_bn[0][0]']
#  on)
#
#  conv3_block12_1_conv (Conv2D)  (None, 28, 28, 128)  61440       ['conv3_block12_0_relu[0][0]']
#
#  conv3_block12_1_bn (BatchNorma  (None, 28, 28, 128)  512        ['conv3_block12_1_conv[0][0]']
#  lization)
#
#  conv3_block12_1_relu (Activati  (None, 28, 28, 128)  0          ['conv3_block12_1_bn[0][0]']
#  on)
#
#  conv3_block12_2_conv (Conv2D)  (None, 28, 28, 32)   36864       ['conv3_block12_1_relu[0][0]']
#
#  conv3_block12_concat (Concaten  (None, 28, 28, 512)  0          ['conv3_block11_concat[0][0]',
#  ate)                                                             'conv3_block12_2_conv[0][0]']
#
#  pool3_bn (BatchNormalization)  (None, 28, 28, 512)  2048        ['conv3_block12_concat[0][0]']
#
#  pool3_relu (Activation)        (None, 28, 28, 512)  0           ['pool3_bn[0][0]']
#
#  pool3_conv (Conv2D)            (None, 28, 28, 256)  131072      ['pool3_relu[0][0]']
#
#  pool3_pool (AveragePooling2D)  (None, 14, 14, 256)  0           ['pool3_conv[0][0]']
#
#  conv4_block1_0_bn (BatchNormal  (None, 14, 14, 256)  1024       ['pool3_pool[0][0]']
#  ization)
#
#  conv4_block1_0_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_0_bn[0][0]']
#  n)
#
#  conv4_block1_1_conv (Conv2D)   (None, 14, 14, 128)  32768       ['conv4_block1_0_relu[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 14, 14, 128)  512        ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 14, 14, 128)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 14, 14, 32)   36864       ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_concat (Concatena  (None, 14, 14, 288)  0          ['pool3_pool[0][0]',
#  te)                                                              'conv4_block1_2_conv[0][0]']
#
#  conv4_block2_0_bn (BatchNormal  (None, 14, 14, 288)  1152       ['conv4_block1_concat[0][0]']
#  ization)
#
#  conv4_block2_0_relu (Activatio  (None, 14, 14, 288)  0          ['conv4_block2_0_bn[0][0]']
#  n)
#
#  conv4_block2_1_conv (Conv2D)   (None, 14, 14, 128)  36864       ['conv4_block2_0_relu[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 14, 14, 128)  512        ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 14, 14, 128)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 14, 14, 32)   36864       ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_concat (Concatena  (None, 14, 14, 320)  0          ['conv4_block1_concat[0][0]',
#  te)                                                              'conv4_block2_2_conv[0][0]']
#
#  conv4_block3_0_bn (BatchNormal  (None, 14, 14, 320)  1280       ['conv4_block2_concat[0][0]']
#  ization)
#
#  conv4_block3_0_relu (Activatio  (None, 14, 14, 320)  0          ['conv4_block3_0_bn[0][0]']
#  n)
#
#  conv4_block3_1_conv (Conv2D)   (None, 14, 14, 128)  40960       ['conv4_block3_0_relu[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 14, 14, 128)  512        ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 14, 14, 128)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 14, 14, 32)   36864       ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_concat (Concatena  (None, 14, 14, 352)  0          ['conv4_block2_concat[0][0]',
#  te)                                                              'conv4_block3_2_conv[0][0]']
#
#  conv4_block4_0_bn (BatchNormal  (None, 14, 14, 352)  1408       ['conv4_block3_concat[0][0]']
#  ization)
#
#  conv4_block4_0_relu (Activatio  (None, 14, 14, 352)  0          ['conv4_block4_0_bn[0][0]']
#  n)
#
#  conv4_block4_1_conv (Conv2D)   (None, 14, 14, 128)  45056       ['conv4_block4_0_relu[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 14, 14, 128)  512        ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 14, 14, 128)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 14, 14, 32)   36864       ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_concat (Concatena  (None, 14, 14, 384)  0          ['conv4_block3_concat[0][0]',
#  te)                                                              'conv4_block4_2_conv[0][0]']
#
#  conv4_block5_0_bn (BatchNormal  (None, 14, 14, 384)  1536       ['conv4_block4_concat[0][0]']
#  ization)
#
#  conv4_block5_0_relu (Activatio  (None, 14, 14, 384)  0          ['conv4_block5_0_bn[0][0]']
#  n)
#
#  conv4_block5_1_conv (Conv2D)   (None, 14, 14, 128)  49152       ['conv4_block5_0_relu[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 14, 14, 128)  512        ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 14, 14, 128)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 14, 14, 32)   36864       ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_concat (Concatena  (None, 14, 14, 416)  0          ['conv4_block4_concat[0][0]',
#  te)                                                              'conv4_block5_2_conv[0][0]']
#
#  conv4_block6_0_bn (BatchNormal  (None, 14, 14, 416)  1664       ['conv4_block5_concat[0][0]']
#  ization)
#
#  conv4_block6_0_relu (Activatio  (None, 14, 14, 416)  0          ['conv4_block6_0_bn[0][0]']
#  n)
#
#  conv4_block6_1_conv (Conv2D)   (None, 14, 14, 128)  53248       ['conv4_block6_0_relu[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 14, 14, 128)  512        ['conv4_block6_1_conv[0][0]']
# ...
# Epoch 11/100
# 40/40 [==============================] - 71s 2s/step - loss: 0.0957 - accuracy: 0.9617 - auc: 0.9937 - val_loss: 0.2658 - val_accuracy: 0.8979 - val_auc: 0.9618
# Epoch 12/100
# 40/40 [==============================] - 19s 474ms/step - loss: 0.0746 - accuracy: 0.9742 - auc: 0.9963 - val_loss: 0.4922 - val_accuracy: 0.7875 - val_auc: 0.9100
# Epoch 13/100
# 40/40 [==============================] - 71s 2s/step - loss: 0.0981 - accuracy: 0.9625 - auc: 0.9940 - val_loss: 0.1752 - val_accuracy: 0.9229 - val_auc: 0.9820
# Epoch 14/100
# 40/40 [==============================] - 20s 488ms/step - loss: 0.0804 - accuracy: 0.9680 - auc: 0.9962 - val_loss: 0.4554 - val_accuracy: 0.8521 - val_auc: 0.9376
# Epoch 15/100
# 40/40 [==============================] - 20s 496ms/step - loss: 0.0785 - accuracy: 0.9719 - auc: 0.9962 - val_loss: 0.5050 - val_accuracy: 0.8729 - val_auc: 0.9324
# Epoch 16/100
# 40/40 [==============================] - 20s 489ms/step - loss: 0.0728 - accuracy: 0.9695 - auc: 0.9969 - val_loss: 0.6722 - val_accuracy: 0.7771 - val_auc: 0.8706
# Epoch 17/100
# 40/40 [==============================] - 19s 489ms/step - loss: 0.0811 - accuracy: 0.9734 - auc: 0.9952 - val_loss: 0.4335 - val_accuracy: 0.8250 - val_auc: 0.9390
# Epoch 18/100
# 40/40 [==============================] - 19s 487ms/step - loss: 0.0638 - accuracy: 0.9750 - auc: 0.9963 - val_loss: 0.3398 - val_accuracy: 0.8708 - val_auc: 0.9502
# Epoch 19/100
# 40/40 [==============================] - 19s 478ms/step - loss: 0.0663 - accuracy: 0.9773 - auc: 0.9966 - val_loss: 0.2645 - val_accuracy: 0.8833 - val_auc: 0.9566
# Epoch 20/100
# 40/40 [==============================] - 20s 492ms/step - loss: 0.0673 - accuracy: 0.9742 - auc: 0.9970 - val_loss: 0.2857 - val_accuracy: 0.8542 - val_auc: 0.9473
# Epoch 21/100
# 40/40 [==============================] - 70s 2s/step - loss: 0.0519 - accuracy: 0.9789 - auc: 0.9978 - val_loss: 0.1600 - val_accuracy: 0.9354 - val_auc: 0.9870
# Epoch 22/100
# 40/40 [==============================] - 19s 487ms/step - loss: 0.0517 - accuracy: 0.9812 - auc: 0.9984 - val_loss: 0.5189 - val_accuracy: 0.8292 - val_auc: 0.9220
# Epoch 23/100
# 40/40 [==============================] - 20s 495ms/step - loss: 0.0473 - accuracy: 0.9836 - auc: 0.9986 - val_loss: 0.3063 - val_accuracy: 0.8938 - val_auc: 0.9593
# Epoch 24/100
# 40/40 [==============================] - 19s 478ms/step - loss: 0.0856 - accuracy: 0.9648 - auc: 0.9956 - val_loss: 0.2749 - val_accuracy: 0.8729 - val_auc: 0.9518
# Epoch 25/100
# 40/40 [==============================] - 19s 484ms/step - loss: 0.0450 - accuracy: 0.9805 - auc: 0.9988 - val_loss: 0.3968 - val_accuracy: 0.8083 - val_auc: 0.9030
# Epoch 26/100
# 40/40 [==============================] - 19s 486ms/step - loss: 0.0424 - accuracy: 0.9859 - auc: 0.9988 - val_loss: 0.8073 - val_accuracy: 0.7854 - val_auc: 0.8711
# Epoch 27/100
# 40/40 [==============================] - 19s 479ms/step - loss: 0.0521 - accuracy: 0.9781 - auc: 0.9984 - val_loss: 0.1804 - val_accuracy: 0.9104 - val_auc: 0.9794
# Epoch 28/100
# 40/40 [==============================] - 19s 476ms/step - loss: 0.0764 - accuracy: 0.9727 - auc: 0.9958 - val_loss: 1.5419 - val_accuracy: 0.7021 - val_auc: 0.7767
# Epoch 29/100
# 40/40 [==============================] - 19s 488ms/step - loss: 0.0302 - accuracy: 0.9875 - auc: 0.9995 - val_loss: 0.4654 - val_accuracy: 0.8417 - val_auc: 0.9372
# Epoch 30/100
# 40/40 [==============================] - 19s 485ms/step - loss: 0.0402 - accuracy: 0.9875 - auc: 0.9982 - val_loss: 0.2547 - val_accuracy: 0.9083 - val_auc: 0.9704
# Epoch 31/100
# 40/40 [==============================] - 19s 488ms/step - loss: 0.0922 - accuracy: 0.9641 - auc: 0.9948 - val_loss: 1.0240 - val_accuracy: 0.7937 - val_auc: 0.8636
# Epoch 32/100
# 40/40 [==============================] - 19s 476ms/step - loss: 0.0341 - accuracy: 0.9875 - auc: 0.9994 - val_loss: 0.2937 - val_accuracy: 0.8938 - val_auc: 0.9768
# Epoch 33/100
# 40/40 [==============================] - 19s 487ms/step - loss: 0.0807 - accuracy: 0.9719 - auc: 0.9953 - val_loss: 0.5257 - val_accuracy: 0.8750 - val_auc: 0.9211
# Epoch 34/100
# 40/40 [==============================] - 19s 488ms/step - loss: 0.0551 - accuracy: 0.9820 - auc: 0.9975 - val_loss: 0.2794 - val_accuracy: 0.9042 - val_auc: 0.9639
# Epoch 35/100
# 40/40 [==============================] - 19s 488ms/step - loss: 0.0321 - accuracy: 0.9875 - auc: 0.9994 - val_loss: 0.2788 - val_accuracy: 0.9000 - val_auc: 0.9678
# Epoch 36/100
# 40/40 [==============================] - 19s 474ms/step - loss: 0.0607 - accuracy: 0.9750 - auc: 0.9972 - val_loss: 0.3161 - val_accuracy: 0.8750 - val_auc: 0.9483
# Epoch 37/100
# 40/40 [==============================] - 19s 489ms/step - loss: 0.0459 - accuracy: 0.9820 - auc: 0.9987 - val_loss: 0.3560 - val_accuracy: 0.9042 - val_auc: 0.9656
# Epoch 38/100
# 40/40 [==============================] - 19s 474ms/step - loss: 0.0250 - accuracy: 0.9891 - auc: 0.9996 - val_loss: 0.3618 - val_accuracy: 0.8854 - val_auc: 0.9548
# Epoch 39/100
# 40/40 [==============================] - 19s 477ms/step - loss: 0.0738 - accuracy: 0.9758 - auc: 0.9961 - val_loss: 0.3148 - val_accuracy: 0.8813 - val_auc: 0.9448
# Epoch 40/100
# 40/40 [==============================] - 19s 479ms/step - loss: 0.0410 - accuracy: 0.9852 - auc: 0.9990 - val_loss: 0.2791 - val_accuracy: 0.9146 - val_auc: 0.9622
# Epoch 41/100
# 40/40 [==============================] - 19s 488ms/step - loss: 0.0641 - accuracy: 0.9742 - auc: 0.9975 - val_loss: 1.0734 - val_accuracy: 0.7583 - val_auc: 0.8301
# Epoch 42/100
# 40/40 [==============================] - 19s 489ms/step - loss: 0.0322 - accuracy: 0.9875 - auc: 0.9994 - val_loss: 0.4010 - val_accuracy: 0.8708 - val_auc: 0.9506
# Epoch 43/100
# 40/40 [==============================] - 19s 488ms/step - loss: 0.0594 - accuracy: 0.9789 - auc: 0.9963 - val_loss: 0.2902 - val_accuracy: 0.9021 - val_auc: 0.9632
# Epoch 44/100
# 40/40 [==============================] - 19s 475ms/step - loss: 0.0256 - accuracy: 0.9898 - auc: 0.9997 - val_loss: 1.3190 - val_accuracy: 0.7375 - val_auc: 0.8262
# Epoch 45/100
# 40/40 [==============================] - 19s 481ms/step - loss: 0.0444 - accuracy: 0.9828 - auc: 0.9983 - val_loss: 0.3510 - val_accuracy: 0.8687 - val_auc: 0.9520
# Epoch 46/100
# 40/40 [==============================] - 19s 474ms/step - loss: 0.0287 - accuracy: 0.9867 - auc: 0.9995 - val_loss: 0.3745 - val_accuracy: 0.9021 - val_auc: 0.9467
# Epoch 47/100
# 40/40 [==============================] - 19s 488ms/step - loss: 0.0228 - accuracy: 0.9898 - auc: 0.9997 - val_loss: 0.2263 - val_accuracy: 0.9125 - val_auc: 0.9775
# Epoch 48/100
# 40/40 [==============================] - 71s 2s/step - loss: 0.0208 - accuracy: 0.9914 - auc: 0.9998 - val_loss: 0.1946 - val_accuracy: 0.9375 - val_auc: 0.9806
# Epoch 49/100
# 40/40 [==============================] - 19s 487ms/step - loss: 0.0191 - accuracy: 0.9937 - auc: 0.9997 - val_loss: 0.2002 - val_accuracy: 0.9083 - val_auc: 0.9828
# Epoch 50/100
# 40/40 [==============================] - 20s 493ms/step - loss: 0.0600 - accuracy: 0.9797 - auc: 0.9980 - val_loss: 0.3364 - val_accuracy: 0.8750 - val_auc: 0.9558
# Epoch 51/100
# 40/40 [==============================] - 19s 489ms/step - loss: 0.0612 - accuracy: 0.9781 - auc: 0.9971 - val_loss: 0.3124 - val_accuracy: 0.8958 - val_auc: 0.9632
# Epoch 52/100
# 40/40 [==============================] - 19s 474ms/step - loss: 0.0174 - accuracy: 0.9961 - auc: 0.9999 - val_loss: 0.4363 - val_accuracy: 0.8958 - val_auc: 0.9421
# Epoch 53/100
# 40/40 [==============================] - 19s 487ms/step - loss: 0.0150 - accuracy: 0.9937 - auc: 0.9999 - val_loss: 0.3651 - val_accuracy: 0.8750 - val_auc: 0.9569
# Epoch 54/100
# 40/40 [==============================] - 19s 475ms/step - loss: 0.0667 - accuracy: 0.9742 - auc: 0.9971 - val_loss: 0.4194 - val_accuracy: 0.8708 - val_auc: 0.9427
# Epoch 55/100
# 40/40 [==============================] - 20s 490ms/step - loss: 0.0389 - accuracy: 0.9883 - auc: 0.9990 - val_loss: 0.1797 - val_accuracy: 0.9375 - val_auc: 0.9875
# Epoch 56/100
# 40/40 [==============================] - 19s 488ms/step - loss: 0.0280 - accuracy: 0.9906 - auc: 0.9995 - val_loss: 0.2420 - val_accuracy: 0.9146 - val_auc: 0.9752
# Epoch 57/100
# 40/40 [==============================] - 19s 484ms/step - loss: 0.0278 - accuracy: 0.9914 - auc: 0.9988 - val_loss: 0.2627 - val_accuracy: 0.9167 - val_auc: 0.9689
# Epoch 58/100
# 40/40 [==============================] - 19s 473ms/step - loss: 0.0316 - accuracy: 0.9883 - auc: 0.9993 - val_loss: 1.5183 - val_accuracy: 0.7063 - val_auc: 0.7727
# Epoch 59/100
# 40/40 [==============================] - 19s 475ms/step - loss: 0.0183 - accuracy: 0.9922 - auc: 0.9998 - val_loss: 0.3366 - val_accuracy: 0.9250 - val_auc: 0.9653
# Epoch 60/100
# 40/40 [==============================] - 19s 488ms/step - loss: 0.0357 - accuracy: 0.9859 - auc: 0.9993 - val_loss: 0.3782 - val_accuracy: 0.9167 - val_auc: 0.9517
# Epoch 61/100
# 40/40 [==============================] - 20s 489ms/step - loss: 0.0440 - accuracy: 0.9867 - auc: 0.9987 - val_loss: 0.2072 - val_accuracy: 0.9250 - val_auc: 0.9811
# Epoch 62/100
# 40/40 [==============================] - 20s 490ms/step - loss: 0.0239 - accuracy: 0.9906 - auc: 0.9996 - val_loss: 0.2988 - val_accuracy: 0.9250 - val_auc: 0.9730
# Epoch 63/100
# 40/40 [==============================] - 19s 474ms/step - loss: 0.0267 - accuracy: 0.9937 - auc: 0.9981 - val_loss: 0.2515 - val_accuracy: 0.9062 - val_auc: 0.9761
# Epoch 64/100
# 40/40 [==============================] - 19s 476ms/step - loss: 0.0201 - accuracy: 0.9914 - auc: 0.9998 - val_loss: 0.4779 - val_accuracy: 0.8938 - val_auc: 0.9311
# Epoch 65/100
# 40/40 [==============================] - 19s 487ms/step - loss: 0.0548 - accuracy: 0.9797 - auc: 0.9983 - val_loss: 0.2416 - val_accuracy: 0.9104 - val_auc: 0.9694
# Epoch 66/100
# 40/40 [==============================] - 19s 476ms/step - loss: 0.0284 - accuracy: 0.9867 - auc: 0.9996 - val_loss: 0.8810 - val_accuracy: 0.7646 - val_auc: 0.8580
# Epoch 67/100
# 40/40 [==============================] - 20s 490ms/step - loss: 0.0113 - accuracy: 0.9953 - auc: 0.9999 - val_loss: 0.4297 - val_accuracy: 0.9021 - val_auc: 0.9416
# Epoch 68/100
# 40/40 [==============================] - 19s 488ms/step - loss: 0.0352 - accuracy: 0.9859 - auc: 0.9986 - val_loss: 0.9334 - val_accuracy: 0.8167 - val_auc: 0.8873
# Epoch 69/100
# 40/40 [==============================] - 19s 475ms/step - loss: 0.0461 - accuracy: 0.9852 - auc: 0.9987 - val_loss: 0.4121 - val_accuracy: 0.8854 - val_auc: 0.9345
# Epoch 70/100
# 40/40 [==============================] - 20s 496ms/step - loss: 0.0168 - accuracy: 0.9945 - auc: 0.9999 - val_loss: 0.3296 - val_accuracy: 0.8833 - val_auc: 0.9592
# Epoch 71/100
# 40/40 [==============================] - 20s 489ms/step - loss: 0.0192 - accuracy: 0.9922 - auc: 0.9998 - val_loss: 0.3229 - val_accuracy: 0.9125 - val_auc: 0.9659
# Epoch 72/100
# 40/40 [==============================] - 19s 476ms/step - loss: 0.0277 - accuracy: 0.9867 - auc: 0.9996 - val_loss: 0.3449 - val_accuracy: 0.8792 - val_auc: 0.9475
# Epoch 73/100
# 40/40 [==============================] - 19s 472ms/step - loss: 0.0370 - accuracy: 0.9891 - auc: 0.9971 - val_loss: 3.0144 - val_accuracy: 0.6021 - val_auc: 0.6412
# Epoch 74/100
# 40/40 [==============================] - 19s 478ms/step - loss: 0.0626 - accuracy: 0.9766 - auc: 0.9971 - val_loss: 2.3698 - val_accuracy: 0.6500 - val_auc: 0.6780
# Epoch 75/100
# 40/40 [==============================] - 19s 487ms/step - loss: 0.0333 - accuracy: 0.9883 - auc: 0.9993 - val_loss: 0.3103 - val_accuracy: 0.8896 - val_auc: 0.9739
# Epoch 76/100
# 40/40 [==============================] - 19s 486ms/step - loss: 0.0134 - accuracy: 0.9937 - auc: 0.9999 - val_loss: 0.2490 - val_accuracy: 0.9354 - val_auc: 0.9762
# Epoch 77/100
# 40/40 [==============================] - 19s 475ms/step - loss: 0.0317 - accuracy: 0.9891 - auc: 0.9994 - val_loss: 0.2868 - val_accuracy: 0.9312 - val_auc: 0.9734
# Epoch 78/100
# 40/40 [==============================] - 19s 487ms/step - loss: 0.0421 - accuracy: 0.9844 - auc: 0.9983 - val_loss: 0.4545 - val_accuracy: 0.8396 - val_auc: 0.9082
# Epoch 79/100
# 40/40 [==============================] - 19s 475ms/step - loss: 0.0215 - accuracy: 0.9922 - auc: 0.9998 - val_loss: 0.2399 - val_accuracy: 0.9354 - val_auc: 0.9817
# Epoch 80/100
# 40/40 [==============================] - 19s 485ms/step - loss: 0.0213 - accuracy: 0.9930 - auc: 0.9997 - val_loss: 0.3174 - val_accuracy: 0.9167 - val_auc: 0.9747
# Epoch 81/100
# 40/40 [==============================] - 71s 2s/step - loss: 0.0199 - accuracy: 0.9922 - auc: 0.9997 - val_loss: 0.1136 - val_accuracy: 0.9625 - val_auc: 0.9917
# Epoch 82/100
# 40/40 [==============================] - 19s 487ms/step - loss: 0.0160 - accuracy: 0.9945 - auc: 0.9998 - val_loss: 0.2687 - val_accuracy: 0.9167 - val_auc: 0.9737
# Epoch 83/100
# 40/40 [==============================] - 19s 489ms/step - loss: 0.0273 - accuracy: 0.9937 - auc: 0.9987 - val_loss: 0.6966 - val_accuracy: 0.8292 - val_auc: 0.9222
# Epoch 84/100
# 40/40 [==============================] - 19s 489ms/step - loss: 0.0147 - accuracy: 0.9969 - auc: 0.9998 - val_loss: 0.3252 - val_accuracy: 0.9167 - val_auc: 0.9644
# Epoch 85/100
# 40/40 [==============================] - 19s 468ms/step - loss: 0.0290 - accuracy: 0.9922 - auc: 0.9980 - val_loss: 0.2229 - val_accuracy: 0.9375 - val_auc: 0.9840
# Epoch 86/100
# 40/40 [==============================] - 19s 486ms/step - loss: 0.0192 - accuracy: 0.9937 - auc: 0.9998 - val_loss: 0.2649 - val_accuracy: 0.9042 - val_auc: 0.9702
# Epoch 87/100
# 40/40 [==============================] - 19s 473ms/step - loss: 0.0305 - accuracy: 0.9914 - auc: 0.9994 - val_loss: 0.2326 - val_accuracy: 0.9354 - val_auc: 0.9729
# Epoch 88/100
# 40/40 [==============================] - 19s 474ms/step - loss: 0.0144 - accuracy: 0.9961 - auc: 0.9999 - val_loss: 0.5032 - val_accuracy: 0.8542 - val_auc: 0.9442
# Epoch 89/100
# 40/40 [==============================] - 19s 487ms/step - loss: 0.0150 - accuracy: 0.9945 - auc: 0.9991 - val_loss: 0.1884 - val_accuracy: 0.9583 - val_auc: 0.9806
# Epoch 90/100
# 40/40 [==============================] - 19s 485ms/step - loss: 0.0379 - accuracy: 0.9875 - auc: 0.9972 - val_loss: 0.6501 - val_accuracy: 0.8333 - val_auc: 0.9078
# Epoch 91/100
# 40/40 [==============================] - 19s 475ms/step - loss: 0.0169 - accuracy: 0.9969 - auc: 0.9991 - val_loss: 0.4526 - val_accuracy: 0.8875 - val_auc: 0.9589
# Epoch 92/100
# 40/40 [==============================] - 19s 473ms/step - loss: 0.0355 - accuracy: 0.9867 - auc: 0.9993 - val_loss: 0.2586 - val_accuracy: 0.9333 - val_auc: 0.9747
# Epoch 93/100
# 40/40 [==============================] - 19s 474ms/step - loss: 0.0182 - accuracy: 0.9937 - auc: 0.9998 - val_loss: 0.2096 - val_accuracy: 0.9438 - val_auc: 0.9757
# Epoch 94/100
# 40/40 [==============================] - 70s 2s/step - loss: 0.0053 - accuracy: 1.0000 - auc: 1.0000 - val_loss: 0.1445 - val_accuracy: 0.9646 - val_auc: 0.9918
# Epoch 95/100
# 40/40 [==============================] - 19s 487ms/step - loss: 0.0030 - accuracy: 0.9992 - auc: 1.0000 - val_loss: 0.2373 - val_accuracy: 0.9438 - val_auc: 0.9860
# Epoch 96/100
# 40/40 [==============================] - 20s 492ms/step - loss: 0.0266 - accuracy: 0.9891 - auc: 0.9989 - val_loss: 0.4918 - val_accuracy: 0.8958 - val_auc: 0.9371
# Epoch 97/100
# 40/40 [==============================] - 19s 480ms/step - loss: 0.0388 - accuracy: 0.9859 - auc: 0.9991 - val_loss: 0.2730 - val_accuracy: 0.9208 - val_auc: 0.9691
# Epoch 98/100
# 40/40 [==============================] - 19s 475ms/step - loss: 0.0402 - accuracy: 0.9867 - auc: 0.9977 - val_loss: 0.3686 - val_accuracy: 0.8979 - val_auc: 0.9520
# Epoch 99/100
# 40/40 [==============================] - 19s 484ms/step - loss: 0.0181 - accuracy: 0.9937 - auc: 0.9998 - val_loss: 0.3666 - val_accuracy: 0.9208 - val_auc: 0.9707
# Epoch 100/100
# 40/40 [==============================] - 20s 490ms/step - loss: 0.0267 - accuracy: 0.9875 - auc: 0.9996 - val_loss: 1.7778 - val_accuracy: 0.7271 - val_auc: 0.7612

# %%
#####TEST SCRIPT#####

import os
import cv2
import random
import numpy as np
import tensorflow as tf
import pandas as pd
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.metrics import confusion_matrix


class test():
    def get_filpath(self, dirname):
        test_files = []
        for x in os.walk(dirname):
            for y in glob.glob(os.path.join(x[0], '*.png')):
                test_files.append(y)

        return test_files
        
    def get_input(self, path):
        input = cv2.imread(path)
        input = cv2.resize(input, (224, 224))
        input = input.reshape(-1, 224, 224, 3)
        return input
    
    def get_output(self, path):
        labaF = [1,0]
        labaT = [0,1]
        label = (path.split('/')[7]).split('_')[0]
        #print(label)
        if 'fake' == label:
            return labaF
        else:
            return labaT

    def load_model(self, modpath):
        mod = tf.keras.models.load_model(modpath)
        return mod

    def test(self, paths, modpath):
        true_label = []
        predicted = []
        mod = self.load_model(modpath)
        positive = 0
        for path in paths:
            im = self.get_input(path)
            lab = self.get_output(path)
            
            pred_label = np.argmax(mod.predict(im))
            predicted.append(pred_label)

            real_label = np.argmax(lab)
            true_label.append(real_label)
            if pred_label == real_label:
                positive = positive + 1
            #print("Filepath : {}, Predicted Label = {}, True Label = {}".format(path, pred_label, real_label))

        FPR, TPR, threshold1 = roc_curve(true_label, predicted)
        print(FPR, TPR, threshold1)
        aucSci = roc_auc_score(true_label, predicted)
        print('Auc score scikit: ', aucSci)
        pd.DataFrame(confusion_matrix(true_label, predicted), columns=['Predicted Fake', "Predicted Real"], index=['Actual Fake', 'Actual Real'])
        print(pd)
        return positive/len(paths), FPR, TPR


    def run(self, dirname, modpath):
        paths = self.get_filpath(dirname)
        random.shuffle(paths)
        res, FPR, TPR = self.test(paths, modpath)

        return res, FPR, TPR

# %%
if __name__=='__main__':
    dirname = '/kaggle/input/deepfake/FaceForensic/FaceForensic/test'  #PATH OF TEST DATA DIRECTORY
    modpath = '/kaggle/working/checkpoint'  #PATH OF TRAINED MODEL
    acc, FPR, TPR = test().run(dirname, modpath)
    print("Test Accuracy = {}".format(acc))
# Out:
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# [0.   0.05 1.  ] [0.         0.97979798 1.        ] [2 1 0]
# Auc score scikit:  0.9648989898989898
# <module 'pandas' from '/opt/conda/lib/python3.7/site-packages/pandas/__init__.py'>
# Test Accuracy = 0.964824120603015

# %%
# Making listing of files & store it in .csv file
import glob
import pandas as pd
CSVFile = '/kaggle/input/deepfake/test.csv'
lstFiles = glob.glob1("/kaggle/input/deepfake/CelebImageDataset/Celeb Image Dataset/testImage", "*.png")
print(len(lstFiles))
df = pd.DataFrame(lstFiles)
df.to_csv(CSVFile, header = False, index=False)
# Out:
# 518
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /tmp/ipykernel_23/2894645288.py in <module>
#       6 print(len(lstFiles))
#       7 df = pd.DataFrame(lstFiles)
# ----> 8 df.to_csv(CSVFile, header = False, index=False)
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3480             doublequote=doublequote,
#    3481             escapechar=escapechar,
# -> 3482             storage_options=storage_options,
#    3483         )
#    3484
#
# /opt/conda/lib/python3.7/site-packages/pandas/io/formats/format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1103             formatter=self.fmt,
#    1104         )
# -> 1105         csv_formatter.save()
#    1106
#    1107         if created_buffer:
#
# /opt/conda/lib/python3.7/site-packages/pandas/io/formats/csvs.py in save(self)
#     241             errors=self.errors,
#     242             compression=self.compression,
# --> 243             storage_options=self.storage_options,
#     244         ) as handles:
#     245
#
# /opt/conda/lib/python3.7/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     705                 encoding=ioargs.encoding,
#     706                 errors=errors,
# --> 707                 newline="",
#     708             )
#     709         else:
#
# OSError: [Errno 30] Read-only file system: '/kaggle/input/deepfake/test.csv'

# %%
#Feature Extraction using Xception

# %%
import pandas as pd

imgList = pd.read_csv('/kaggle/input/labels/test_FF.csv', index_col=False, header = None)
imgList = imgList[imgList.columns[0]].tolist()

FeatureFileName = '/kaggle/working/Main_Test.csv'
print(len(imgList))
# Out:
# 199

# %%
def get_input(path):
    im = cv2.imread(path)
    im = cv2.resize(im,(224,224))
    im = im.reshape(-1,224,224,3)
    
    return(im)

# %%
from keras.utils.vis_utils import plot_model
plot_model(mod,show_shapes=True,to_file="abc.png")

# %%
import tensorflow as tf
mod = tf.keras.models.load_model('/kaggle/input/labels/callback')
mod = tf.keras.Model(inputs=mod.input, outputs=mod.layers[-3].output)

# %%
mod.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  zero_padding2d (ZeroPadding2D)  (None, 230, 230, 3)  0          ['input_1[0][0]']
#
#  conv1/conv (Conv2D)            (None, 112, 112, 64  9408        ['zero_padding2d[0][0]']
#                                 )
#
#  conv1/bn (BatchNormalization)  (None, 112, 112, 64  256         ['conv1/conv[0][0]']
#                                 )
#
#  conv1/relu (Activation)        (None, 112, 112, 64  0           ['conv1/bn[0][0]']
#                                 )
#
#  zero_padding2d_1 (ZeroPadding2  (None, 114, 114, 64  0          ['conv1/relu[0][0]']
#  D)                             )
#
#  pool1 (MaxPooling2D)           (None, 56, 56, 64)   0           ['zero_padding2d_1[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 56, 56, 64)  256         ['pool1[0][0]']
#  ization)
#
#  conv2_block1_0_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_0_bn[0][0]']
#  n)
#
#  conv2_block1_1_conv (Conv2D)   (None, 56, 56, 128)  8192        ['conv2_block1_0_relu[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 56, 56, 128)  512        ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 56, 56, 128)  0          ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 56, 56, 32)   36864       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_concat (Concatena  (None, 56, 56, 96)  0           ['pool1[0][0]',
#  te)                                                              'conv2_block1_2_conv[0][0]']
#
#  conv2_block2_0_bn (BatchNormal  (None, 56, 56, 96)  384         ['conv2_block1_concat[0][0]']
#  ization)
#
#  conv2_block2_0_relu (Activatio  (None, 56, 56, 96)  0           ['conv2_block2_0_bn[0][0]']
#  n)
#
#  conv2_block2_1_conv (Conv2D)   (None, 56, 56, 128)  12288       ['conv2_block2_0_relu[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 56, 56, 128)  512        ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 56, 56, 128)  0          ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 56, 56, 32)   36864       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_concat (Concatena  (None, 56, 56, 128)  0          ['conv2_block1_concat[0][0]',
#  te)                                                              'conv2_block2_2_conv[0][0]']
#
#  conv2_block3_0_bn (BatchNormal  (None, 56, 56, 128)  512        ['conv2_block2_concat[0][0]']
#  ization)
#
#  conv2_block3_0_relu (Activatio  (None, 56, 56, 128)  0          ['conv2_block3_0_bn[0][0]']
#  n)
#
#  conv2_block3_1_conv (Conv2D)   (None, 56, 56, 128)  16384       ['conv2_block3_0_relu[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 56, 56, 128)  512        ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 56, 56, 128)  0          ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 56, 56, 32)   36864       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_concat (Concatena  (None, 56, 56, 160)  0          ['conv2_block2_concat[0][0]',
#  te)                                                              'conv2_block3_2_conv[0][0]']
#
#  conv2_block4_0_bn (BatchNormal  (None, 56, 56, 160)  640        ['conv2_block3_concat[0][0]']
#  ization)
#
#  conv2_block4_0_relu (Activatio  (None, 56, 56, 160)  0          ['conv2_block4_0_bn[0][0]']
#  n)
#
#  conv2_block4_1_conv (Conv2D)   (None, 56, 56, 128)  20480       ['conv2_block4_0_relu[0][0]']
#
#  conv2_block4_1_bn (BatchNormal  (None, 56, 56, 128)  512        ['conv2_block4_1_conv[0][0]']
#  ization)
#
#  conv2_block4_1_relu (Activatio  (None, 56, 56, 128)  0          ['conv2_block4_1_bn[0][0]']
#  n)
#
#  conv2_block4_2_conv (Conv2D)   (None, 56, 56, 32)   36864       ['conv2_block4_1_relu[0][0]']
#
#  conv2_block4_concat (Concatena  (None, 56, 56, 192)  0          ['conv2_block3_concat[0][0]',
#  te)                                                              'conv2_block4_2_conv[0][0]']
#
#  conv2_block5_0_bn (BatchNormal  (None, 56, 56, 192)  768        ['conv2_block4_concat[0][0]']
#  ization)
#
#  conv2_block5_0_relu (Activatio  (None, 56, 56, 192)  0          ['conv2_block5_0_bn[0][0]']
#  n)
#
#  conv2_block5_1_conv (Conv2D)   (None, 56, 56, 128)  24576       ['conv2_block5_0_relu[0][0]']
#
#  conv2_block5_1_bn (BatchNormal  (None, 56, 56, 128)  512        ['conv2_block5_1_conv[0][0]']
#  ization)
#
#  conv2_block5_1_relu (Activatio  (None, 56, 56, 128)  0          ['conv2_block5_1_bn[0][0]']
#  n)
#
#  conv2_block5_2_conv (Conv2D)   (None, 56, 56, 32)   36864       ['conv2_block5_1_relu[0][0]']
#
#  conv2_block5_concat (Concatena  (None, 56, 56, 224)  0          ['conv2_block4_concat[0][0]',
#  te)                                                              'conv2_block5_2_conv[0][0]']
#
#  conv2_block6_0_bn (BatchNormal  (None, 56, 56, 224)  896        ['conv2_block5_concat[0][0]']
#  ization)
#
#  conv2_block6_0_relu (Activatio  (None, 56, 56, 224)  0          ['conv2_block6_0_bn[0][0]']
#  n)
#
#  conv2_block6_1_conv (Conv2D)   (None, 56, 56, 128)  28672       ['conv2_block6_0_relu[0][0]']
#
#  conv2_block6_1_bn (BatchNormal  (None, 56, 56, 128)  512        ['conv2_block6_1_conv[0][0]']
#  ization)
#
#  conv2_block6_1_relu (Activatio  (None, 56, 56, 128)  0          ['conv2_block6_1_bn[0][0]']
#  n)
#
#  conv2_block6_2_conv (Conv2D)   (None, 56, 56, 32)   36864       ['conv2_block6_1_relu[0][0]']
#
#  conv2_block6_concat (Concatena  (None, 56, 56, 256)  0          ['conv2_block5_concat[0][0]',
#  te)                                                              'conv2_block6_2_conv[0][0]']
#
#  pool2_bn (BatchNormalization)  (None, 56, 56, 256)  1024        ['conv2_block6_concat[0][0]']
#
#  pool2_relu (Activation)        (None, 56, 56, 256)  0           ['pool2_bn[0][0]']
#
#  pool2_conv (Conv2D)            (None, 56, 56, 128)  32768       ['pool2_relu[0][0]']
#
#  pool2_pool (AveragePooling2D)  (None, 28, 28, 128)  0           ['pool2_conv[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 28, 28, 128)  512        ['pool2_pool[0][0]']
#  ization)
#
#  conv3_block1_0_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_0_bn[0][0]']
#  n)
#
#  conv3_block1_1_conv (Conv2D)   (None, 28, 28, 128)  16384       ['conv3_block1_0_relu[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_concat (Concatena  (None, 28, 28, 160)  0          ['pool2_pool[0][0]',
#  te)                                                              'conv3_block1_2_conv[0][0]']
#
#  conv3_block2_0_bn (BatchNormal  (None, 28, 28, 160)  640        ['conv3_block1_concat[0][0]']
#  ization)
#
#  conv3_block2_0_relu (Activatio  (None, 28, 28, 160)  0          ['conv3_block2_0_bn[0][0]']
#  n)
#
#  conv3_block2_1_conv (Conv2D)   (None, 28, 28, 128)  20480       ['conv3_block2_0_relu[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_concat (Concatena  (None, 28, 28, 192)  0          ['conv3_block1_concat[0][0]',
#  te)                                                              'conv3_block2_2_conv[0][0]']
#
#  conv3_block3_0_bn (BatchNormal  (None, 28, 28, 192)  768        ['conv3_block2_concat[0][0]']
#  ization)
#
#  conv3_block3_0_relu (Activatio  (None, 28, 28, 192)  0          ['conv3_block3_0_bn[0][0]']
#  n)
#
#  conv3_block3_1_conv (Conv2D)   (None, 28, 28, 128)  24576       ['conv3_block3_0_relu[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_concat (Concatena  (None, 28, 28, 224)  0          ['conv3_block2_concat[0][0]',
#  te)                                                              'conv3_block3_2_conv[0][0]']
#
#  conv3_block4_0_bn (BatchNormal  (None, 28, 28, 224)  896        ['conv3_block3_concat[0][0]']
#  ization)
#
#  conv3_block4_0_relu (Activatio  (None, 28, 28, 224)  0          ['conv3_block4_0_bn[0][0]']
#  n)
#
#  conv3_block4_1_conv (Conv2D)   (None, 28, 28, 128)  28672       ['conv3_block4_0_relu[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_concat (Concatena  (None, 28, 28, 256)  0          ['conv3_block3_concat[0][0]',
#  te)                                                              'conv3_block4_2_conv[0][0]']
#
#  conv3_block5_0_bn (BatchNormal  (None, 28, 28, 256)  1024       ['conv3_block4_concat[0][0]']
#  ization)
#
#  conv3_block5_0_relu (Activatio  (None, 28, 28, 256)  0          ['conv3_block5_0_bn[0][0]']
#  n)
#
#  conv3_block5_1_conv (Conv2D)   (None, 28, 28, 128)  32768       ['conv3_block5_0_relu[0][0]']
#
#  conv3_block5_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block5_1_conv[0][0]']
#  ization)
#
#  conv3_block5_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block5_1_bn[0][0]']
#  n)
#
#  conv3_block5_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block5_1_relu[0][0]']
#
#  conv3_block5_concat (Concatena  (None, 28, 28, 288)  0          ['conv3_block4_concat[0][0]',
#  te)                                                              'conv3_block5_2_conv[0][0]']
#
#  conv3_block6_0_bn (BatchNormal  (None, 28, 28, 288)  1152       ['conv3_block5_concat[0][0]']
#  ization)
#
#  conv3_block6_0_relu (Activatio  (None, 28, 28, 288)  0          ['conv3_block6_0_bn[0][0]']
#  n)
#
#  conv3_block6_1_conv (Conv2D)   (None, 28, 28, 128)  36864       ['conv3_block6_0_relu[0][0]']
#
#  conv3_block6_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block6_1_conv[0][0]']
#  ization)
#
#  conv3_block6_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block6_1_bn[0][0]']
#  n)
#
#  conv3_block6_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block6_1_relu[0][0]']
#
#  conv3_block6_concat (Concatena  (None, 28, 28, 320)  0          ['conv3_block5_concat[0][0]',
#  te)                                                              'conv3_block6_2_conv[0][0]']
#
#  conv3_block7_0_bn (BatchNormal  (None, 28, 28, 320)  1280       ['conv3_block6_concat[0][0]']
#  ization)
#
#  conv3_block7_0_relu (Activatio  (None, 28, 28, 320)  0          ['conv3_block7_0_bn[0][0]']
#  n)
#
#  conv3_block7_1_conv (Conv2D)   (None, 28, 28, 128)  40960       ['conv3_block7_0_relu[0][0]']
#
#  conv3_block7_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block7_1_conv[0][0]']
#  ization)
#
#  conv3_block7_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block7_1_bn[0][0]']
#  n)
#
#  conv3_block7_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block7_1_relu[0][0]']
#
#  conv3_block7_concat (Concatena  (None, 28, 28, 352)  0          ['conv3_block6_concat[0][0]',
#  te)                                                              'conv3_block7_2_conv[0][0]']
#
#  conv3_block8_0_bn (BatchNormal  (None, 28, 28, 352)  1408       ['conv3_block7_concat[0][0]']
#  ization)
#
#  conv3_block8_0_relu (Activatio  (None, 28, 28, 352)  0          ['conv3_block8_0_bn[0][0]']
#  n)
#
#  conv3_block8_1_conv (Conv2D)   (None, 28, 28, 128)  45056       ['conv3_block8_0_relu[0][0]']
#
#  conv3_block8_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block8_1_conv[0][0]']
#  ization)
#
#  conv3_block8_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block8_1_bn[0][0]']
#  n)
#
#  conv3_block8_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block8_1_relu[0][0]']
#
#  conv3_block8_concat (Concatena  (None, 28, 28, 384)  0          ['conv3_block7_concat[0][0]',
#  te)                                                              'conv3_block8_2_conv[0][0]']
#
#  conv3_block9_0_bn (BatchNormal  (None, 28, 28, 384)  1536       ['conv3_block8_concat[0][0]']
#  ization)
#
#  conv3_block9_0_relu (Activatio  (None, 28, 28, 384)  0          ['conv3_block9_0_bn[0][0]']
#  n)
#
#  conv3_block9_1_conv (Conv2D)   (None, 28, 28, 128)  49152       ['conv3_block9_0_relu[0][0]']
#
#  conv3_block9_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block9_1_conv[0][0]']
#  ization)
#
#  conv3_block9_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block9_1_bn[0][0]']
#  n)
#
#  conv3_block9_2_conv (Conv2D)   (None, 28, 28, 32)   36864       ['conv3_block9_1_relu[0][0]']
#
#  conv3_block9_concat (Concatena  (None, 28, 28, 416)  0          ['conv3_block8_concat[0][0]',
#  te)                                                              'conv3_block9_2_conv[0][0]']
#
#  conv3_block10_0_bn (BatchNorma  (None, 28, 28, 416)  1664       ['conv3_block9_concat[0][0]']
#  lization)
#
#  conv3_block10_0_relu (Activati  (None, 28, 28, 416)  0          ['conv3_block10_0_bn[0][0]']
#  on)
#
#  conv3_block10_1_conv (Conv2D)  (None, 28, 28, 128)  53248       ['conv3_block10_0_relu[0][0]']
#
#  conv3_block10_1_bn (BatchNorma  (None, 28, 28, 128)  512        ['conv3_block10_1_conv[0][0]']
#  lization)
#
#  conv3_block10_1_relu (Activati  (None, 28, 28, 128)  0          ['conv3_block10_1_bn[0][0]']
#  on)
#
#  conv3_block10_2_conv (Conv2D)  (None, 28, 28, 32)   36864       ['conv3_block10_1_relu[0][0]']
#
#  conv3_block10_concat (Concaten  (None, 28, 28, 448)  0          ['conv3_block9_concat[0][0]',
#  ate)                                                             'conv3_block10_2_conv[0][0]']
#
#  conv3_block11_0_bn (BatchNorma  (None, 28, 28, 448)  1792       ['conv3_block10_concat[0][0]']
#  lization)
#
#  conv3_block11_0_relu (Activati  (None, 28, 28, 448)  0          ['conv3_block11_0_bn[0][0]']
#  on)
#
#  conv3_block11_1_conv (Conv2D)  (None, 28, 28, 128)  57344       ['conv3_block11_0_relu[0][0]']
#
#  conv3_block11_1_bn (BatchNorma  (None, 28, 28, 128)  512        ['conv3_block11_1_conv[0][0]']
#  lization)
#
#  conv3_block11_1_relu (Activati  (None, 28, 28, 128)  0          ['conv3_block11_1_bn[0][0]']
#  on)
#
#  conv3_block11_2_conv (Conv2D)  (None, 28, 28, 32)   36864       ['conv3_block11_1_relu[0][0]']
#
#  conv3_block11_concat (Concaten  (None, 28, 28, 480)  0          ['conv3_block10_concat[0][0]',
#  ate)                                                             'conv3_block11_2_conv[0][0]']
#
#  conv3_block12_0_bn (BatchNorma  (None, 28, 28, 480)  1920       ['conv3_block11_concat[0][0]']
#  lization)
#
#  conv3_block12_0_relu (Activati  (None, 28, 28, 480)  0          ['conv3_block12_0_bn[0][0]']
#  on)
#
#  conv3_block12_1_conv (Conv2D)  (None, 28, 28, 128)  61440       ['conv3_block12_0_relu[0][0]']
#
#  conv3_block12_1_bn (BatchNorma  (None, 28, 28, 128)  512        ['conv3_block12_1_conv[0][0]']
#  lization)
#
#  conv3_block12_1_relu (Activati  (None, 28, 28, 128)  0          ['conv3_block12_1_bn[0][0]']
#  on)
#
#  conv3_block12_2_conv (Conv2D)  (None, 28, 28, 32)   36864       ['conv3_block12_1_relu[0][0]']
#
#  conv3_block12_concat (Concaten  (None, 28, 28, 512)  0          ['conv3_block11_concat[0][0]',
#  ate)                                                             'conv3_block12_2_conv[0][0]']
#
#  pool3_bn (BatchNormalization)  (None, 28, 28, 512)  2048        ['conv3_block12_concat[0][0]']
#
#  pool3_relu (Activation)        (None, 28, 28, 512)  0           ['pool3_bn[0][0]']
#
#  pool3_conv (Conv2D)            (None, 28, 28, 256)  131072      ['pool3_relu[0][0]']
#
#  pool3_pool (AveragePooling2D)  (None, 14, 14, 256)  0           ['pool3_conv[0][0]']
#
#  conv4_block1_0_bn (BatchNormal  (None, 14, 14, 256)  1024       ['pool3_pool[0][0]']
#  ization)
#
#  conv4_block1_0_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_0_bn[0][0]']
#  n)
#
#  conv4_block1_1_conv (Conv2D)   (None, 14, 14, 128)  32768       ['conv4_block1_0_relu[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 14, 14, 128)  512        ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 14, 14, 128)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 14, 14, 32)   36864       ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_concat (Concatena  (None, 14, 14, 288)  0          ['pool3_pool[0][0]',
#  te)                                                              'conv4_block1_2_conv[0][0]']
#
#  conv4_block2_0_bn (BatchNormal  (None, 14, 14, 288)  1152       ['conv4_block1_concat[0][0]']
#  ization)
#
#  conv4_block2_0_relu (Activatio  (None, 14, 14, 288)  0          ['conv4_block2_0_bn[0][0]']
#  n)
#
#  conv4_block2_1_conv (Conv2D)   (None, 14, 14, 128)  36864       ['conv4_block2_0_relu[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 14, 14, 128)  512        ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 14, 14, 128)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 14, 14, 32)   36864       ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_concat (Concatena  (None, 14, 14, 320)  0          ['conv4_block1_concat[0][0]',
#  te)                                                              'conv4_block2_2_conv[0][0]']
#
#  conv4_block3_0_bn (BatchNormal  (None, 14, 14, 320)  1280       ['conv4_block2_concat[0][0]']
#  ization)
#
#  conv4_block3_0_relu (Activatio  (None, 14, 14, 320)  0          ['conv4_block3_0_bn[0][0]']
#  n)
#
#  conv4_block3_1_conv (Conv2D)   (None, 14, 14, 128)  40960       ['conv4_block3_0_relu[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 14, 14, 128)  512        ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 14, 14, 128)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 14, 14, 32)   36864       ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_concat (Concatena  (None, 14, 14, 352)  0          ['conv4_block2_concat[0][0]',
#  te)                                                              'conv4_block3_2_conv[0][0]']
#
#  conv4_block4_0_bn (BatchNormal  (None, 14, 14, 352)  1408       ['conv4_block3_concat[0][0]']
#  ization)
#
#  conv4_block4_0_relu (Activatio  (None, 14, 14, 352)  0          ['conv4_block4_0_bn[0][0]']
#  n)
#
#  conv4_block4_1_conv (Conv2D)   (None, 14, 14, 128)  45056       ['conv4_block4_0_relu[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 14, 14, 128)  512        ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 14, 14, 128)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 14, 14, 32)   36864       ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_concat (Concatena  (None, 14, 14, 384)  0          ['conv4_block3_concat[0][0]',
#  te)                                                              'conv4_block4_2_conv[0][0]']
#
#  conv4_block5_0_bn (BatchNormal  (None, 14, 14, 384)  1536       ['conv4_block4_concat[0][0]']
#  ization)
#
#  conv4_block5_0_relu (Activatio  (None, 14, 14, 384)  0          ['conv4_block5_0_bn[0][0]']
#  n)
#
#  conv4_block5_1_conv (Conv2D)   (None, 14, 14, 128)  49152       ['conv4_block5_0_relu[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 14, 14, 128)  512        ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 14, 14, 128)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 14, 14, 32)   36864       ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_concat (Concatena  (None, 14, 14, 416)  0          ['conv4_block4_concat[0][0]',
#  te)                                                              'conv4_block5_2_conv[0][0]']
#
#  conv4_block6_0_bn (BatchNormal  (None, 14, 14, 416)  1664       ['conv4_block5_concat[0][0]']
#  ization)
#
#  conv4_block6_0_relu (Activatio  (None, 14, 14, 416)  0          ['conv4_block6_0_bn[0][0]']
#  n)
#
#  conv4_block6_1_conv (Conv2D)   (None, 14, 14, 128)  53248       ['conv4_block6_0_relu[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 14, 14, 128)  512        ['conv4_block6_1_conv[0][0]']
# ...
#  ization)
#
#  conv5_block9_0_relu (Activatio  (None, 7, 7, 768)   0           ['conv5_block9_0_bn[0][0]']
#  n)
#
#  conv5_block9_1_conv (Conv2D)   (None, 7, 7, 128)    98304       ['conv5_block9_0_relu[0][0]']
#
#  conv5_block9_1_bn (BatchNormal  (None, 7, 7, 128)   512         ['conv5_block9_1_conv[0][0]']
#  ization)
#
#  conv5_block9_1_relu (Activatio  (None, 7, 7, 128)   0           ['conv5_block9_1_bn[0][0]']
#  n)
#
#  conv5_block9_2_conv (Conv2D)   (None, 7, 7, 32)     36864       ['conv5_block9_1_relu[0][0]']
#
#  conv5_block9_concat (Concatena  (None, 7, 7, 800)   0           ['conv5_block8_concat[0][0]',
#  te)                                                              'conv5_block9_2_conv[0][0]']
#
#  conv5_block10_0_bn (BatchNorma  (None, 7, 7, 800)   3200        ['conv5_block9_concat[0][0]']
#  lization)
#
#  conv5_block10_0_relu (Activati  (None, 7, 7, 800)   0           ['conv5_block10_0_bn[0][0]']
#  on)
#
#  conv5_block10_1_conv (Conv2D)  (None, 7, 7, 128)    102400      ['conv5_block10_0_relu[0][0]']
#
#  conv5_block10_1_bn (BatchNorma  (None, 7, 7, 128)   512         ['conv5_block10_1_conv[0][0]']
#  lization)
#
#  conv5_block10_1_relu (Activati  (None, 7, 7, 128)   0           ['conv5_block10_1_bn[0][0]']
#  on)
#
#  conv5_block10_2_conv (Conv2D)  (None, 7, 7, 32)     36864       ['conv5_block10_1_relu[0][0]']
#
#  conv5_block10_concat (Concaten  (None, 7, 7, 832)   0           ['conv5_block9_concat[0][0]',
#  ate)                                                             'conv5_block10_2_conv[0][0]']
#
#  conv5_block11_0_bn (BatchNorma  (None, 7, 7, 832)   3328        ['conv5_block10_concat[0][0]']
#  lization)
#
#  conv5_block11_0_relu (Activati  (None, 7, 7, 832)   0           ['conv5_block11_0_bn[0][0]']
#  on)
#
#  conv5_block11_1_conv (Conv2D)  (None, 7, 7, 128)    106496      ['conv5_block11_0_relu[0][0]']
#
#  conv5_block11_1_bn (BatchNorma  (None, 7, 7, 128)   512         ['conv5_block11_1_conv[0][0]']
#  lization)
#
#  conv5_block11_1_relu (Activati  (None, 7, 7, 128)   0           ['conv5_block11_1_bn[0][0]']
#  on)
#
#  conv5_block11_2_conv (Conv2D)  (None, 7, 7, 32)     36864       ['conv5_block11_1_relu[0][0]']
#
#  conv5_block11_concat (Concaten  (None, 7, 7, 864)   0           ['conv5_block10_concat[0][0]',
#  ate)                                                             'conv5_block11_2_conv[0][0]']
#
#  conv5_block12_0_bn (BatchNorma  (None, 7, 7, 864)   3456        ['conv5_block11_concat[0][0]']
#  lization)
#
#  conv5_block12_0_relu (Activati  (None, 7, 7, 864)   0           ['conv5_block12_0_bn[0][0]']
#  on)
#
#  conv5_block12_1_conv (Conv2D)  (None, 7, 7, 128)    110592      ['conv5_block12_0_relu[0][0]']
#
#  conv5_block12_1_bn (BatchNorma  (None, 7, 7, 128)   512         ['conv5_block12_1_conv[0][0]']
#  lization)
#
#  conv5_block12_1_relu (Activati  (None, 7, 7, 128)   0           ['conv5_block12_1_bn[0][0]']
#  on)
#
#  conv5_block12_2_conv (Conv2D)  (None, 7, 7, 32)     36864       ['conv5_block12_1_relu[0][0]']
#
#  conv5_block12_concat (Concaten  (None, 7, 7, 896)   0           ['conv5_block11_concat[0][0]',
#  ate)                                                             'conv5_block12_2_conv[0][0]']
#
#  conv5_block13_0_bn (BatchNorma  (None, 7, 7, 896)   3584        ['conv5_block12_concat[0][0]']
#  lization)
#
#  conv5_block13_0_relu (Activati  (None, 7, 7, 896)   0           ['conv5_block13_0_bn[0][0]']
#  on)
#
#  conv5_block13_1_conv (Conv2D)  (None, 7, 7, 128)    114688      ['conv5_block13_0_relu[0][0]']
#
#  conv5_block13_1_bn (BatchNorma  (None, 7, 7, 128)   512         ['conv5_block13_1_conv[0][0]']
#  lization)
#
#  conv5_block13_1_relu (Activati  (None, 7, 7, 128)   0           ['conv5_block13_1_bn[0][0]']
#  on)
#
#  conv5_block13_2_conv (Conv2D)  (None, 7, 7, 32)     36864       ['conv5_block13_1_relu[0][0]']
#
#  conv5_block13_concat (Concaten  (None, 7, 7, 928)   0           ['conv5_block12_concat[0][0]',
#  ate)                                                             'conv5_block13_2_conv[0][0]']
#
#  conv5_block14_0_bn (BatchNorma  (None, 7, 7, 928)   3712        ['conv5_block13_concat[0][0]']
#  lization)
#
#  conv5_block14_0_relu (Activati  (None, 7, 7, 928)   0           ['conv5_block14_0_bn[0][0]']
#  on)
#
#  conv5_block14_1_conv (Conv2D)  (None, 7, 7, 128)    118784      ['conv5_block14_0_relu[0][0]']
#
#  conv5_block14_1_bn (BatchNorma  (None, 7, 7, 128)   512         ['conv5_block14_1_conv[0][0]']
#  lization)
#
#  conv5_block14_1_relu (Activati  (None, 7, 7, 128)   0           ['conv5_block14_1_bn[0][0]']
#  on)
#
#  conv5_block14_2_conv (Conv2D)  (None, 7, 7, 32)     36864       ['conv5_block14_1_relu[0][0]']
#
#  conv5_block14_concat (Concaten  (None, 7, 7, 960)   0           ['conv5_block13_concat[0][0]',
#  ate)                                                             'conv5_block14_2_conv[0][0]']
#
#  conv5_block15_0_bn (BatchNorma  (None, 7, 7, 960)   3840        ['conv5_block14_concat[0][0]']
#  lization)
#
#  conv5_block15_0_relu (Activati  (None, 7, 7, 960)   0           ['conv5_block15_0_bn[0][0]']
#  on)
#
#  conv5_block15_1_conv (Conv2D)  (None, 7, 7, 128)    122880      ['conv5_block15_0_relu[0][0]']
#
#  conv5_block15_1_bn (BatchNorma  (None, 7, 7, 128)   512         ['conv5_block15_1_conv[0][0]']
#  lization)
#
#  conv5_block15_1_relu (Activati  (None, 7, 7, 128)   0           ['conv5_block15_1_bn[0][0]']
#  on)
#
#  conv5_block15_2_conv (Conv2D)  (None, 7, 7, 32)     36864       ['conv5_block15_1_relu[0][0]']
#
#  conv5_block15_concat (Concaten  (None, 7, 7, 992)   0           ['conv5_block14_concat[0][0]',
#  ate)                                                             'conv5_block15_2_conv[0][0]']
#
#  conv5_block16_0_bn (BatchNorma  (None, 7, 7, 992)   3968        ['conv5_block15_concat[0][0]']
#  lization)
#
#  conv5_block16_0_relu (Activati  (None, 7, 7, 992)   0           ['conv5_block16_0_bn[0][0]']
#  on)
#
#  conv5_block16_1_conv (Conv2D)  (None, 7, 7, 128)    126976      ['conv5_block16_0_relu[0][0]']
#
#  conv5_block16_1_bn (BatchNorma  (None, 7, 7, 128)   512         ['conv5_block16_1_conv[0][0]']
#  lization)
#
#  conv5_block16_1_relu (Activati  (None, 7, 7, 128)   0           ['conv5_block16_1_bn[0][0]']
#  on)
#
#  conv5_block16_2_conv (Conv2D)  (None, 7, 7, 32)     36864       ['conv5_block16_1_relu[0][0]']
#
#  conv5_block16_concat (Concaten  (None, 7, 7, 1024)  0           ['conv5_block15_concat[0][0]',
#  ate)                                                             'conv5_block16_2_conv[0][0]']
#
#  bn (BatchNormalization)        (None, 7, 7, 1024)   4096        ['conv5_block16_concat[0][0]']
#
#  relu (Activation)              (None, 7, 7, 1024)   0           ['bn[0][0]']
#
#  avg_pool (GlobalAveragePooling  (None, 1024)        0           ['relu[0][0]']
#  2D)
#
# ==================================================================================================
# Total params: 7,037,504
# Trainable params: 6,953,856
# Non-trainable params: 83,648
# __________________________________________________________________________________________________

# %%
def convertFeatureDatatoCSV(all_features):
    tmpList = []
    #Last column store class value
    
    feature_dimention = len(all_features[0]) - 1
    print(feature_dimention)
    #Prepare column header string for csv file
    #for heading in range (feature_dimention):
    #    strng = 'attr-' + str(heading)
    #    tmpList.append(strng)
    #tmpList.append('class')
    
    #all_features.insert(0, tmpList)
    df = pd.DataFrame(all_features)
    df.to_csv(FeatureFileName, header = False, index=False)

# %%
import cv2
feature = []
i=0
for img in imgList:
    if 'fake' in img:
        typ = 1
    else:
        typ = 0
    imgPath = '/kaggle/input/deepfake/FaceForensic/FaceForensic/test/' + img
    print(imgPath)
    out = mod.predict(get_input(imgPath))
    out = out.tolist()
    flatten_list = [j for sub in out for j in sub]
    flatten_list.append(typ)
    feature.append(flatten_list)
    print(i)
    i += 1
convertFeatureDatatoCSV(feature)
# Out:
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_004_982_frame154.png
# 1/1 [==============================] - 10s 10s/step
# 0
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_007_132_frame252.png
# 1/1 [==============================] - 0s 42ms/step
# 1
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_011_805_frame316.png
# 1/1 [==============================] - 0s 42ms/step
# 2
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_029_048_frame208.png
# 1/1 [==============================] - 0s 42ms/step
# 3
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_044_945_frame167.png
# 1/1 [==============================] - 0s 45ms/step
# 4
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_045_889_frame175.png
# 1/1 [==============================] - 0s 42ms/step
# 5
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_049_946_frame180.png
# 1/1 [==============================] - 0s 42ms/step
# 6
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_056_996_frame186.png
# 1/1 [==============================] - 0s 40ms/step
# 7
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_064_991_frame201.png
# 1/1 [==============================] - 0s 43ms/step
# 8
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_070_057_frame183.png
# 1/1 [==============================] - 0s 45ms/step
# 9
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_078_955_frame261.png
# 1/1 [==============================] - 0s 44ms/step
# 10
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_085_124_frame164.png
# 1/1 [==============================] - 0s 43ms/step
# 11
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_090_086_frame343.png
# 1/1 [==============================] - 0s 98ms/step
# 12
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_122_144_frame154.png
# 1/1 [==============================] - 0s 40ms/step
# 13
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_134_192_frame173.png
# 1/1 [==============================] - 0s 40ms/step
# 14
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_143_140_frame207.png
# 1/1 [==============================] - 0s 41ms/step
# 15
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_193_030_frame186.png
# 1/1 [==============================] - 0s 40ms/step
# 16
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_200_189_frame359.png
# 1/1 [==============================] - 0s 41ms/step
# 17
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_205_184_frame153.png
# 1/1 [==============================] - 0s 43ms/step
# 18
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_211_177_frame263.png
# 1/1 [==============================] - 0s 42ms/step
# 19
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_228_289_frame278.png
# 1/1 [==============================] - 0s 40ms/step
# 20
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_239_218_frame294.png
# 1/1 [==============================] - 0s 41ms/step
# 21
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_241_210_frame146.png
# 1/1 [==============================] - 0s 42ms/step
# 22
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_255_214_frame235.png
# 1/1 [==============================] - 0s 42ms/step
# 23
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_284_263_frame241.png
# 1/1 [==============================] - 0s 42ms/step
# 24
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_286_267_frame334.png
# 1/1 [==============================] - 0s 42ms/step
# 25
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_288_321_frame271.png
# 1/1 [==============================] - 0s 41ms/step
# 26
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_291_874_frame165.png
# 1/1 [==============================] - 0s 43ms/step
# 27
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_299_145_frame157.png
# 1/1 [==============================] - 0s 45ms/step
# 28
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_304_300_frame305.png
# 1/1 [==============================] - 0s 44ms/step
# 29
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_315_322_frame152.png
# 1/1 [==============================] - 0s 41ms/step
# 30
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_316_369_frame283.png
# 1/1 [==============================] - 0s 43ms/step
# 31
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_325_492_frame710.png
# 1/1 [==============================] - 0s 41ms/step
# 32
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_335_277_frame192.png
# 1/1 [==============================] - 0s 41ms/step
# 33
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_353_383_frame179.png
# 1/1 [==============================] - 0s 41ms/step
# 34
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_371_367_frame359.png
# 1/1 [==============================] - 0s 41ms/step
# 35
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_383_353_frame232.png
# 1/1 [==============================] - 0s 44ms/step
# 36
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_387_311_frame264.png
# 1/1 [==============================] - 0s 40ms/step
# 37
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_391_406_frame273.png
# 1/1 [==============================] - 0s 41ms/step
# 38
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_402_453_frame211.png
# 1/1 [==============================] - 0s 41ms/step
# 39
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_422_695_frame158.png
# 1/1 [==============================] - 0s 44ms/step
# 40
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_425_485_frame168.png
# 1/1 [==============================] - 0s 41ms/step
# 41
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_435_456_frame238.png
# 1/1 [==============================] - 0s 42ms/step
# 42
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_477_487_frame182.png
# 1/1 [==============================] - 0s 41ms/step
# 43
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_484_415_frame159.png
# 1/1 [==============================] - 0s 40ms/step
# 44
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_499_539_frame257.png
# 1/1 [==============================] - 0s 40ms/step
# 45
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_512_495_frame375.png
# 1/1 [==============================] - 0s 37ms/step
# 46
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_516_555_frame177.png
# 1/1 [==============================] - 0s 42ms/step
# 47
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_539_499_frame156.png
# 1/1 [==============================] - 0s 41ms/step
# 48
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_544_532_frame177.png
# 1/1 [==============================] - 0s 44ms/step
# 49
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_548_632_frame286.png
# 1/1 [==============================] - 0s 42ms/step
# 50
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_552_851_frame151.png
# 1/1 [==============================] - 0s 43ms/step
# 51
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_560_557_frame174.png
# 1/1 [==============================] - 0s 43ms/step
# 52
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_563_537_frame195.png
# 1/1 [==============================] - 0s 40ms/step
# 53
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_593_577_frame267.png
# 1/1 [==============================] - 0s 41ms/step
# 54
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_596_609_frame278.png
# 1/1 [==============================] - 0s 42ms/step
# 55
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_602_397_frame333.png
# 1/1 [==============================] - 0s 39ms/step
# 56
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_610_692_frame197.png
# 1/1 [==============================] - 0s 41ms/step
# 57
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_613_685_frame207.png
# 1/1 [==============================] - 0s 41ms/step
# 58
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_616_614_frame331.png
# 1/1 [==============================] - 0s 40ms/step
# 59
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_626_562_frame487.png
# 1/1 [==============================] - 0s 40ms/step
# 60
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_628_568_frame447.png
# 1/1 [==============================] - 0s 41ms/step
# 61
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_652_773_frame228.png
# 1/1 [==============================] - 0s 41ms/step
# 62
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_655_444_frame339.png
# 1/1 [==============================] - 0s 41ms/step
# 63
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_662_641_frame248.png
# 1/1 [==============================] - 0s 37ms/step
# 64
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_678_460_frame200.png
# 1/1 [==============================] - 0s 46ms/step
# 65
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_721_715_frame290.png
# 1/1 [==============================] - 0s 42ms/step
# 66
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_732_691_frame213.png
# 1/1 [==============================] - 0s 42ms/step
# 67
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_743_750_frame155.png
# 1/1 [==============================] - 0s 43ms/step
# 68
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_745_777_frame284.png
# 1/1 [==============================] - 0s 44ms/step
# 69
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_759_755_frame217.png
# 1/1 [==============================] - 0s 43ms/step
# 70
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_761_766_frame171.png
# 1/1 [==============================] - 0s 41ms/step
# 71
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_763_930_frame406.png
# 1/1 [==============================] - 0s 42ms/step
# 72
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_782_787_frame278.png
# 1/1 [==============================] - 0s 40ms/step
# 73
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_800_840_frame169.png
# 1/1 [==============================] - 0s 40ms/step
# 74
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_817_827_frame209.png
# 1/1 [==============================] - 0s 39ms/step
# 75
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_819_786_frame463.png
# 1/1 [==============================] - 0s 41ms/step
# 76
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_826_833_frame177.png
# 1/1 [==============================] - 0s 43ms/step
# 77
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_835_651_frame213.png
# 1/1 [==============================] - 0s 42ms/step
# 78
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_845_846_frame178.png
# 1/1 [==============================] - 0s 41ms/step
# 79
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_850_764_frame306.png
# 1/1 [==============================] - 0s 43ms/step
# 80
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_851_552_frame416.png
# 1/1 [==============================] - 0s 41ms/step
# 81
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_857_909_frame320.png
# 1/1 [==============================] - 0s 41ms/step
# 82
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_860_905_frame229.png
# 1/1 [==============================] - 0s 41ms/step
# 83
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_872_873_frame237.png
# 1/1 [==============================] - 0s 39ms/step
# 84
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_887_275_frame169.png
# 1/1 [==============================] - 0s 41ms/step
# 85
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_909_857_frame318.png
# 1/1 [==============================] - 0s 42ms/step
# 86
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_910_911_frame146.png
# 1/1 [==============================] - 0s 44ms/step
# 87
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_913_893_frame317.png
# 1/1 [==============================] - 0s 41ms/step
# 88
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_938_987_frame184.png
# 1/1 [==============================] - 0s 40ms/step
# 89
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_940_941_frame154.png
# 1/1 [==============================] - 0s 40ms/step
# 90
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_950_836_frame381.png
# 1/1 [==============================] - 0s 40ms/step
# 91
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_954_976_frame188.png
# 1/1 [==============================] - 0s 39ms/step
# 92
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_958_956_frame196.png
# 1/1 [==============================] - 0s 44ms/step
# 93
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_962_929_frame230.png
# 1/1 [==============================] - 0s 41ms/step
# 94
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_967_984_frame206.png
# 1/1 [==============================] - 0s 83ms/step
# 95
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_969_897_frame178.png
# 1/1 [==============================] - 0s 42ms/step
# 96
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_972_718_frame155.png
# 1/1 [==============================] - 0s 42ms/step
# 97
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_974_953_frame159.png
# 1/1 [==============================] - 0s 40ms/step
# 98
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/fake_976_954_frame164.png
# 1/1 [==============================] - 0s 42ms/step
# 99
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_004_frame154.png
# 1/1 [==============================] - 0s 43ms/step
# 100
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_008_frame318.png
# 1/1 [==============================] - 0s 44ms/step
# 101
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_012_frame181.png
# 1/1 [==============================] - 0s 40ms/step
# 102
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_018_frame216.png
# 1/1 [==============================] - 0s 42ms/step
# 103
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_033_frame404.png
# 1/1 [==============================] - 0s 40ms/step
# 104
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_034_frame203.png
# 1/1 [==============================] - 0s 42ms/step
# 105
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_037_frame227.png
# 1/1 [==============================] - 0s 43ms/step
# 106
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_041_frame174.png
# 1/1 [==============================] - 0s 43ms/step
# 107
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_043_frame247.png
# 1/1 [==============================] - 0s 43ms/step
# 108
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_059_frame360.png
# 1/1 [==============================] - 0s 43ms/step
# 109
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_068_frame200.png
# 1/1 [==============================] - 0s 40ms/step
# 110
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_073_frame351.png
# 1/1 [==============================] - 0s 43ms/step
# 111
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_074_frame172.png
# 1/1 [==============================] - 0s 40ms/step
# 112
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_075_frame306.png
# 1/1 [==============================] - 0s 41ms/step
# 113
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_090_frame343.png
# 1/1 [==============================] - 0s 43ms/step
# 114
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_111_frame216.png
# 1/1 [==============================] - 0s 42ms/step
# 115
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_113_frame420.png
# 1/1 [==============================] - 0s 43ms/step
# 116
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_120_frame202.png
# 1/1 [==============================] - 0s 43ms/step
# 117
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_130_frame331.png
# 1/1 [==============================] - 0s 41ms/step
# 118
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_132_frame206.png
# 1/1 [==============================] - 0s 39ms/step
# 119
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_135_frame163.png
# 1/1 [==============================] - 0s 42ms/step
# 120
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_159_frame162.png
# 1/1 [==============================] - 0s 40ms/step
# 121
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_163_frame152.png
# 1/1 [==============================] - 0s 40ms/step
# 122
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_166_frame378.png
# 1/1 [==============================] - 0s 41ms/step
# 123
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_180_frame284.png
# 1/1 [==============================] - 0s 42ms/step
# 124
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_186_frame167.png
# 1/1 [==============================] - 0s 41ms/step
# 125
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_212_frame207.png
# 1/1 [==============================] - 0s 42ms/step
# 126
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_230_frame186.png
# 1/1 [==============================] - 0s 42ms/step
# 127
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_239_frame294.png
# 1/1 [==============================] - 0s 43ms/step
# 128
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_243_frame193.png
# 1/1 [==============================] - 0s 45ms/step
# 129
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_259_frame222.png
# 1/1 [==============================] - 0s 42ms/step
# 130
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_260_frame151.png
# 1/1 [==============================] - 0s 42ms/step
# 131
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_271_frame245.png
# 1/1 [==============================] - 0s 43ms/step
# 132
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_272_frame161.png
# 1/1 [==============================] - 0s 43ms/step
# 133
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_283_frame483.png
# 1/1 [==============================] - 0s 43ms/step
# 134
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_295_frame205.png
# 1/1 [==============================] - 0s 42ms/step
# 135
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_299_frame157.png
# 1/1 [==============================] - 0s 40ms/step
# 136
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_312_frame214.png
# 1/1 [==============================] - 0s 41ms/step
# 137
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_314_frame206.png
# 1/1 [==============================] - 0s 40ms/step
# 138
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_320_frame252.png
# 1/1 [==============================] - 0s 41ms/step
# 139
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_344_frame315.png
# 1/1 [==============================] - 0s 41ms/step
# 140
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_345_frame211.png
# 1/1 [==============================] - 0s 40ms/step
# 141
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_351_frame342.png
# 1/1 [==============================] - 0s 41ms/step
# 142
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_354_frame230.png
# 1/1 [==============================] - 0s 43ms/step
# 143
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_359_frame228.png
# 1/1 [==============================] - 0s 41ms/step
# 144
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_362_frame227.png
# 1/1 [==============================] - 0s 42ms/step
# 145
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_369_frame160.png
# 1/1 [==============================] - 0s 43ms/step
# 146
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_374_frame293.png
# 1/1 [==============================] - 0s 40ms/step
# 147
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_397_frame177.png
# 1/1 [==============================] - 0s 43ms/step
# 148
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_399_frame431.png
# 1/1 [==============================] - 0s 40ms/step
# 149
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_430_frame178.png
# 1/1 [==============================] - 0s 42ms/step
# 150
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_440_frame209.png
# 1/1 [==============================] - 0s 41ms/step
# 151
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_445_frame526.png
# 1/1 [==============================] - 0s 42ms/step
# 152
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_460_frame320.png
# 1/1 [==============================] - 0s 41ms/step
# 153
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_464_frame202.png
# 1/1 [==============================] - 0s 42ms/step
# 154
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_487_frame159.png
# 1/1 [==============================] - 0s 43ms/step
# 155
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_494_frame401.png
# 1/1 [==============================] - 0s 43ms/step
# 156
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_503_frame337.png
# 1/1 [==============================] - 0s 42ms/step
# 157
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_509_frame281.png
# 1/1 [==============================] - 0s 41ms/step
# 158
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_536_frame301.png
# 1/1 [==============================] - 0s 42ms/step
# 159
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_537_frame192.png
# 1/1 [==============================] - 0s 42ms/step
# 160
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_545_frame218.png
# 1/1 [==============================] - 0s 43ms/step
# 161
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_558_frame267.png
# 1/1 [==============================] - 0s 42ms/step
# 162
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_560_frame174.png
# 1/1 [==============================] - 0s 45ms/step
# 163
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_563_frame195.png
# 1/1 [==============================] - 0s 42ms/step
# 164
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_571_frame288.png
# 1/1 [==============================] - 0s 42ms/step
# 165
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_572_frame173.png
# 1/1 [==============================] - 0s 41ms/step
# 166
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_576_frame230.png
# 1/1 [==============================] - 0s 41ms/step
# 167
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_585_frame179.png
# 1/1 [==============================] - 0s 41ms/step
# 168
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_597_frame148.png
# 1/1 [==============================] - 0s 42ms/step
# 169
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_618_frame191.png
# 1/1 [==============================] - 0s 42ms/step
# 170
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_628_frame447.png
# 1/1 [==============================] - 0s 43ms/step
# 171
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_638_frame349.png
# 1/1 [==============================] - 0s 41ms/step
# 172
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_639_frame331.png
# 1/1 [==============================] - 0s 42ms/step
# 173
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_643_frame182.png
# 1/1 [==============================] - 0s 41ms/step
# 174
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_650_frame346.png
# 1/1 [==============================] - 0s 41ms/step
# 175
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_657_frame273.png
# 1/1 [==============================] - 0s 42ms/step
# 176
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_658_frame202.png
# 1/1 [==============================] - 0s 41ms/step
# 177
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_694_frame149.png
# 1/1 [==============================] - 0s 45ms/step
# 178
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_697_frame232.png
# 1/1 [==============================] - 0s 101ms/step
# 179
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_699_frame262.png
# 1/1 [==============================] - 0s 44ms/step
# 180
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_707_frame517.png
# 1/1 [==============================] - 0s 42ms/step
# 181
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_713_frame263.png
# 1/1 [==============================] - 0s 43ms/step
# 182
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_747_frame235.png
# 1/1 [==============================] - 0s 41ms/step
# 183
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_772_frame170.png
# 1/1 [==============================] - 0s 39ms/step
# 184
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_822_frame148.png
# 1/1 [==============================] - 0s 41ms/step
# 185
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_828_frame159.png
# 1/1 [==============================] - 0s 44ms/step
# 186
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_854_frame147.png
# 1/1 [==============================] - 0s 41ms/step
# 187
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_860_frame229.png
# 1/1 [==============================] - 0s 43ms/step
# 188
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_862_frame235.png
# 1/1 [==============================] - 0s 43ms/step
# 189
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_874_frame234.png
# 1/1 [==============================] - 0s 43ms/step
# 190
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_887_frame169.png
# 1/1 [==============================] - 0s 41ms/step
# 191
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_930_frame224.png
# 1/1 [==============================] - 0s 42ms/step
# 192
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_938_frame184.png
# 1/1 [==============================] - 0s 41ms/step
# 193
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_944_frame171.png
# 1/1 [==============================] - 0s 41ms/step
# 194
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_957_frame209.png
# 1/1 [==============================] - 0s 39ms/step
# 195
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_962_frame230.png
# 1/1 [==============================] - 0s 42ms/step
# 196
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_969_frame178.png
# 1/1 [==============================] - 0s 42ms/step
# 197
# /kaggle/input/deepfake/FaceForensic/FaceForensic/test/real_999_frame167.png
# 1/1 [==============================] - 0s 44ms/step
# 198
# 1024

# %%
#Train & Test using Xception features [Designed mlp]

# %%
import tensorflow as tf
from keras.layers import Input

mod = tf.keras.Input(shape = (2048,))
layer = tf.keras.layers.Dense(512, activation='relu')(mod)
layer = tf.keras.layers.Dense(2, activation='sigmoid')(layer)
model = tf.keras.models.Model(inputs=mod, outputs=layer)

# %%
import pandas as pd
import random

train_data = pd.read_csv('/content/drive/MyDrive/KhalidTemp/CelebImageDataset/xception_celeb_train_feature.csv', index_col=False, header = None)
train_data = train_data.sample(frac = 1)
y_train = train_data[train_data.columns[-1]]
x_train = train_data.drop(train_data.columns[[-1]], axis=1)

test_data = pd.read_csv('/content/drive/MyDrive/KhalidTemp/CelebImageDataset/xception_celeb_test_feature.csv', index_col=False, header = None)
test_data = test_data.sample(frac = 1)
y_test = test_data[test_data.columns[-1]]
x_test = test_data.drop(test_data.columns[[-1]], axis=1)

# %%
Y_train = []
Y_test = []
for val in y_train:
    if val == 1:
        Y_train.append([1,0])
    else:
        Y_train.append([0,1])
        
for val in y_test:
    if val == 1:
        Y_test.append([1,0])
    else:
        Y_test.append([0,1])
        
y_train = np.asarray(Y_train)
y_test = np.asarray(Y_test)

# %%
# Configure the model and start training
model.compile('Adam', loss = tf.keras.losses.CategoricalCrossentropy(), metrics = ['accuracy', tf.keras.metrics.AUC()])

history = model.fit(x_train, y_train, epochs=200, batch_size=32, steps_per_epoch = 40, verbose=1, validation_steps = 15, validation_batch_size=32, validation_split=0.2)

# %%
#Training MLP

model.compile('Adam', loss = tf.keras.losses.CategoricalCrossentropy(), metrics = ['accuracy', tf.keras.metrics.AUC()])
 
checkpoint_filepath = '/content/checkpoint'
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_filepath, save_best_only=True, save_weights_only=False, monitor='val_accuracy', mode='max')
 
#history = model.fit((train_files, batch_size = 32), epochs = 50, steps_per_epoch = 40, callbacks=[model_checkpoint_callback])
history = model.fit(x_train, y_train, epochs=30, batch_size=32, verbose=1, validation_split=0.2)

# %%
# Test the model after training
test_results = model.evaluate(x_test, y_test, verbose=1)
print(f'Test results - Loss: {test_results[0]} - Accuracy: {test_results[1]}%')
# Out:
# 17/17 [==============================] - 0s 5ms/step - loss: 0.1874 - accuracy: 0.9556 - auc_8: 0.9906
#
#
#
# Test results - Loss: 0.18736720085144043 - Accuracy: 0.9555984735488892%
